# %% [markdown]
# ## Ingest

# %%
import pandas as pd

# %%
df = pd.read_csv('../data/life-expectancy.csv')
df.head()
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                             Indicator Name  Indicator Code       1960  \
# 0  Life expectancy at birth, total (years)  SP.DYN.LE00.IN  64.152000
# 1  Life expectancy at birth, total (years)  SP.DYN.LE00.IN  44.085552
# 2  Life expectancy at birth, total (years)  SP.DYN.LE00.IN  32.535000
# 3  Life expectancy at birth, total (years)  SP.DYN.LE00.IN  37.845152
# 4  Life expectancy at birth, total (years)  SP.DYN.LE00.IN  38.211000
#
#         1961       1962       1963       1964       1965  ...       2015  \
# 0  64.537000  64.752000  65.132000  65.294000  65.502000  ...  75.683000
# 1  44.386697  44.752182  44.913159  45.479043  45.498338  ...  61.856458
# ...

# %%
df.describe()
# Out:
#              1960        1961        1962        1963        1964        1965  \
# count  252.000000  253.000000  253.000000  252.000000  252.000000  252.000000
# mean    53.544867   54.188189   54.826720   55.132891   55.738923   55.998581
# std     11.515064   11.323464   11.038184   10.992228   10.979829   10.994394
# min     28.662000   28.840000   29.119000   28.826000   30.418000   29.288000
# 25%     43.931500   45.336940   45.802340   46.170481   47.357500   47.624752
# 50%     53.724500   54.316000   55.086000   55.567500   56.168671   56.841085
# 75%     64.176500   64.512000   64.579496   64.904274   65.348269   65.963348
# max     73.762049   73.652683   73.721951   73.555366   73.733171   73.868780
#
#              1966        1967        1968        1969  ...        2015  \
# count  253.000000  253.000000  253.000000  253.000000  ...  258.000000
# mean    56.444554   56.863263   57.181864   57.415496  ...   71.672447
# ...

# %%
df.isna().sum()
# Out:
# Country Name        0
# Country Code        0
# Indicator Name      0
# Indicator Code      0
# 1960               14
#                  ...
# 2020                9
# 2021                9
# 2022              266
# 2023              266
# Unnamed: 68       266
# Length: 69, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 69 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    266 non-null    object
#  1   Country Code    266 non-null    object
#  2   Indicator Name  266 non-null    object
#  3   Indicator Code  266 non-null    object
#  4   1960            252 non-null    float64
#  5   1961            253 non-null    float64
#  6   1962            253 non-null    float64
#  7   1963            252 non-null    float64
#  8   1964            252 non-null    float64
#  9   1965            252 non-null    float64
#  10  1966            253 non-null    float64
#  11  1967            253 non-null    float64
#  12  1968            253 non-null    float64
#  13  1969            253 non-null    float64
#  14  1970            253 non-null    float64
#  15  1971            253 non-null    float64
#  16  1972            253 non-null    float64
# ...

# %% [markdown]
# ## EDA

# %%
import seaborn as sns

# %%
sns.FacetGrid(df, col="Country Name")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 sns.FacetGrid(df, col="Country Name")
#
# File /workspace/.pyenv_mirror/user/current/lib/python3.12/site-packages/seaborn/axisgrid.py:532, in FacetGrid.__init__(self, data, row, col, hue, col_wrap, sharex, sharey, height, aspect, palette, row_order, col_order, hue_order, hue_kws, dropna, legend_out, despine, margin_titles, xlim, ylim, subplot_kws, gridspec_kws)
#     529 # --- Make the axes look good
#     531 self.set_titles()
# --> 532 self.tight_layout()
#     534 if despine:
#     535     self.despine()
#
# File /workspace/.pyenv_mirror/user/current/lib/python3.12/site-packages/seaborn/axisgrid.py:123, in Grid.tight_layout(self, *args, **kwargs)
#     121 if self._tight_layout_pad is not None:
#     122     kwargs.setdefault("pad", self._tight_layout_pad)
# ...
